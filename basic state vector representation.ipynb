# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit (2,2)
qc.draw()
# Out:
#
# q_0:
#
# q_1:
#
# c: 2/

# %%
from qiskit import QuantumCircuit, assemble, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
sim = Aer.get_backend('aer_simulator')

# %%
qc = QuantumCircuit(1) 
initial_state = [0,1] 
qc.initialize(initial_state, 0) 
qc.save_statevector() 
qobj = assemble(qc) 
result = sim.run(qobj).result() 
out_state = result.get_statevector()
print(out_state)

qc.measure_all()
qc.draw()
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# C:\Users\agrim\AppData\Local\Temp\ipykernel_22312\631529094.py:6: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = sim.run(qobj).result()
#         ┌─────────────────┐ statevector  ░ ┌─┐
#      q: ┤ Initialize(0,1) ├──────░───────░─┤M├
#         └─────────────────┘      ░       ░ └╥┘
# meas: 1/════════════════════════════════════╩═
#                                             0

# %%
qobj = assemble(qc)
result = sim.run(qobj).result()
counts = result.get_counts()
plot_histogram(counts)
# Out:
# C:\Users\agrim\AppData\Local\Temp\ipykernel_22312\2553066296.py:2: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   result = sim.run(qobj).result()

# %%
initial_state = [1/sqrt(3), 1j/sqrt(3/2)] 
qc = QuantumCircuit(1) 
qc.initialize(initial_state, 0) 
qc.save_statevector() 
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector() 
print(state)
# Out:
# Statevector([0.57735027+0.j        , 0.        +0.81649658j],
#             dims=(2,))
# C:\Users\agrim\AppData\Local\Temp\ipykernel_22312\2199226269.py:6: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
qobj = assemble(qc)
results = sim.run(qobj).result().get_counts()
plot_histogram(results)
# Out:
# C:\Users\agrim\AppData\Local\Temp\ipykernel_22312\3316427587.py:2: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   results = sim.run(qobj).result().get_counts()
